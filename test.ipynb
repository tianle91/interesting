# %%
import pandas as pd
from interest import get_interest_rater


rater_name = 'gpt2'
rater = get_interest_rater(rater_name=rater_name)

# %%
interest_df = pd.DataFrame([
    {'sentence': s, 'interest': rater(s), 'rater_name': rater_name}
    for s in [
        'china is tiny', 'china is small', 'china is big', 'china is large', 'china is massive',
        'china is good', 'china is ok', 'china is bad', 'psngltn fi pentium',
    ]
])
interest_df
# Out:
#              sentence  interest rater_name
# 0       china is tiny  6.825087       gpt2
# 1      china is small  6.516008       gpt2
# 2        china is big  6.520842       gpt2
# 3      china is large  6.715237       gpt2
# 4    china is massive  7.161968       gpt2
# 5       china is good  6.034962       gpt2
# 6         china is ok  7.101572       gpt2
# 7        china is bad  6.455273       gpt2
# 8  psngltn fi pentium  8.425194       gpt2
